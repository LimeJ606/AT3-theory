# %% [markdown]
# # Lesson 01 — Introduction to Machine Learning
# **NSW Software Engineering Stage 6 | Software Automation**
#
# ---
# ### Welcome to Artificial Intelligence!
# Learning to code can feel overwhelming. But today, we are going to take it one tiny step at a time.
#
# Today, you are going to teach a computer to think for itself.
#
# **Your Goals for Today:**
# 1. Understand how Machine Learning is different from normal coding.
# 2. Learn the 3 main "flavours" of Machine Learning.
# 3. Build your very first AI model, one line of code at a time.
#
# Take your time. Read the text, and click **Run** on each code box as you go down the page.

# %%
# 👇 RUN THIS CELL FIRST 👇
# This cell downloads the tools we need to build an AI.
# It might take 10-20 seconds to finish running.

# !pip install numpy scikit-learn --prefer-binary --quiet

import numpy as np
from sklearn.linear_model import LinearRegression

print("✅ Setup Complete! You have all your tools. Move to the next section.")
# Out:
# ✅ Setup Complete! You have all your tools. Move to the next section.

# %% [markdown]
# ---
# ## Concept 1: What is the difference?
#
# How is Artificial Intelligence (AI) different from normal computer programming?
#
# ### Normal Programming (You write the rules)
# In normal coding, **YOU** have to type out every single rule. The computer just follows your exact instructions.
#
# > **Formula:** `Data + Human-Written Rules = Outputs`
#
# **Example:** If you want a program to grade a test, you write the rule yourself:
# *`if score > 50, then print "Pass"`*
#
# ---
#
# ### Machine Learning (The computer learns the rules)
# But what if you want a program to look at a photo and say if it's a Dog or a Cat? You can't write a rule for that!
#
# Instead, we use **Machine Learning**.
# We give the computer thousands of examples (Answers), and ask the computer to figure out the rules mathematically.
#
# > **Formula:** `Data + Answers = The Computer Learns the Rules`

# %% [markdown]
# ---
# ## Concept 2: Let's Build an AI together!
#
# We are going to build a small AI that can predict a student's test score based on how many hours they studied.
#
# We will do this in 4 tiny steps.

# %% [markdown]
# ### Step 1: Give the AI some Data
# An AI needs examples to learn from. Let's give it the data of 4 past students.
#
# * **X (Inputs):** The hours they studied (2, 4, 6, and 8 hours).
# * **y (Answers):** The scores they actually got (50, 60, 70, and 80).

# %%
# 👇 RUN THIS CELL 👇

# The Inputs (Notice the double brackets [[ ]] — this is how the AI likes to read inputs)
X_hours = np.array([[2], [4], [6], [8]])

# The Answers
y_scores = np.array([50, 60, 70, 80])

print("✅ Data has been saved into the computer's memory!")
# Out:
# ✅ Data has been saved into the computer's memory!

# %% [markdown]
# ### Step 2: Create the "Brain"
# Now we need to create an empty AI model. Think of this as a newborn brain — it doesn't know anything yet.
#
# We will use a tool called `LinearRegression()`. This is a math tool that looks for straight-line patterns.

# %%
# 👇 RUN THIS CELL 👇

# Create the empty AI and call it 'my_ai'
my_ai = LinearRegression()

print("✅ Empty AI created! Right now, it knows nothing.")
# Out:
# ✅ Empty AI created! Right now, it knows nothing.

# %% [markdown]
# ### Step 3: Train the Brain!
# This is where the magic happens. We use a command called `.fit()`.
#
# `.fit()` tells the AI: *"Look at the inputs, look at the answers, and find the hidden pattern!"*

# %%
# 👇 RUN THIS CELL 👇

# Train the AI using our data from Step 1
my_ai.fit(X_hours, y_scores)

print("✅ Training complete! The AI has found the pattern.")
# Out:
# ✅ Training complete! The AI has found the pattern.

# %% [markdown]
# ### Step 4: Make a Prediction
# Now that the AI is trained, we can ask it a new question.
# Let's ask it: *"What score will someone get if they study for 5 hours?"*
#
# We use the `.predict()` command for this.

# %%
# 👇 RUN THIS CELL 👇

# Ask the AI to predict the score for 5 hours.
# (Again, we use double brackets [[ ]] for the input)
prediction = my_ai.predict([[5]])

print(f"🤖 The AI predicts that 5 hours of study will result in a score of: {prediction[0]:.0f}")
# Out:
# 🤖 The AI predicts that 5 hours of study will result in a score of: 65

# %% [markdown]
# ---
# ## Concept 3: The Three Flavours of AI
#
# You just built a **Supervised Learning** model! But there are actually 3 different ways to teach an AI:
#
# ### 1. Supervised Learning (Learning with a Teacher)
# * **How it works:** You give the AI the data AND the correct answers (just like we did with the test scores).
# * **Used for:** Predicting numbers (like house prices) or categorising things (like Spam vs Not Spam).
#
# ### 2. Unsupervised Learning (Learning by Exploring)
# * **How it works:** You give the AI a giant pile of data, but NO answers. You ask it to find hidden groups on its own.
# * **Used for:** Spotify looking at millions of users and grouping similar songs into a playlist.
#
# ### 3. Reinforcement Learning (Learning by Trial and Error)
# * **How it works:** The AI plays a "game". It gets a point for doing something good, and loses a point for doing something bad.
# * **Used for:** Teaching a robot to walk, or teaching a self-driving car to stay on the road.

# %% [markdown]
# ---
# ## ✏️ Exercise 1: Build Your Own Bug Identifier
#
# Now it is your turn to write the code. Don't worry, just replace the `____` blanks with the correct words.
#
# **The Problem:**
# You are a biologist. You have recorded the wing sizes of past bugs, and labelled them as Species 0 or Species 1.
# You just found a NEW bug with an **890mm** wing. You need the AI to predict which species it is.
#
# *(If you get stuck, scroll to the Answer Key at the very bottom!)*

# %%
# 👇 FILL IN THE BLANKS AND RUN THIS CELL 👇

bug_wings   = np.array([[850], [870], [900], [920]])
bug_species = np.array([0, 0, 1, 1])
print("1. Data loaded.")

# STEP 1: Create the empty model
# TODO: Replace the ____ with LinearRegression()
bug_ai = LinearRegression()

print("2. AI Created.")

# STEP 2: Train the model
# TODO: Replace the ____ with the word 'fit'
bug_ai.fit(bug_wings, bug_species)

print("3. AI Trained.")

# STEP 3: Make a prediction for an 890mm wing
# TODO: Replace the ____ with the word 'predict'
result = bug_ai.predict([[890]])

print(f"\n🤖 SUCCESS! The AI predicts this bug is Species: {result[0]:.2f}")
# (If the answer is closer to 0 it is Species 0. If closer to 1 it is Species 1)
# Out:
# 1. Data loaded.
# 2. AI Created.
# 3. AI Trained.
#
# 🤖 SUCCESS! The AI predicts this bug is Species: 0.59

# %% [markdown]
# ---
# ## ✏️ Exercise 2: Pick the Right AI
#
# Let's test if you understand the 3 flavours of AI.
# Look at each problem below. Should you use **"regression"**, **"classification"**, or **"clustering"**?
#
# **Your Task:**
# Replace the word `None` with either `"regression"`, `"classification"`, or `"clustering"`.
# *(Keep the quotation marks!)*

# %%
# 👇 FILL IN THE BLANKS AND RUN THIS CELL 👇

scenarios = {
    # Example:
    "Estimating a student's final test score (a number)": "regression",

    # TODO: Fill in the 4 blanks below:
    "Predicting tomorrow's temperature in Celsius (a number)": "regression",
    "Grouping shoppers into unnamed groups based on habits": "clustering",
    "Labelling an email as the category 'Spam' or 'Not Spam'": "classification",
    "Labelling an X-Ray photo as the category 'Broken' or 'Healthy'": "classification",
}

# ⬇️ DON'T EDIT BELOW THIS LINE — THIS IS THE AUTOGRADER ⬇️
answers = {
    "Estimating a student's final test score (a number)": "regression",
    "Predicting tomorrow's temperature in Celsius (a number)": "regression",
    "Grouping shoppers into unnamed groups based on habits": "clustering",
    "Labelling an email as the category 'Spam' or 'Not Spam'": "classification",
    "Labelling an X-Ray photo as the category 'Broken' or 'Healthy'": "classification",
}
score = 0
print("=== Exercise 2 Results ===")
for task, your_ans in scenarios.items():
    if task == "Estimating a student's final test score (a number)":
        continue
    correct = answers[task]
    if your_ans == correct:
        print(f"  ✅ Correct! '{correct}'")
        score += 1
    elif your_ans is None:
        print(f"  ⬜ Not answered yet")
    else:
        print(f"  ❌ You said '{your_ans}', but it should be '{correct}'")
print(f"\nFinal Score: {score}/4")
# Out:
# === Exercise 2 Results ===
#   ✅ Correct! 'regression'
#   ✅ Correct! 'clustering'
#   ✅ Correct! 'classification'
#   ✅ Correct! 'classification'
#
# Final Score: 4/4

# %% [markdown]
# ---
# ## 🚀 EXTENSION CHALLENGES 🚀
# Finished early? Want to push your coding skills further? Try these three harder exercises.
#
# ### Exercise 3: Multiple Inputs at Once
# So far, our AI only looked at *one* input at a time (hours studied, or wing size).
# But in the real world, AI looks at **multiple features** at once.
#
# **The Problem:** You are a real estate agent. You want an AI to predict a house's price based on **both** the number of Bedrooms AND the number of Bathrooms.
#
# To do this, we format inputs like this: `[[Beds, Baths]]`
#
# Fill in the code to train the model and predict the price for a house with **3 Beds and 2 Baths**.

# %%
# 👇 FILL IN THE BLANKS AND RUN THIS CELL 👇

X_houses = np.array([
    [2, 1],   # 2 bed, 1 bath
    [3, 1],   # 3 bed, 1 bath
    [4, 2],   # 4 bed, 2 bath
    [5, 3]    # 5 bed, 3 bath
])
y_prices = np.array([400, 480, 650, 800])  # price in $000s

# 1. Create the model
house_ai = LinearRegression()

# 2. Train the model (Inputs first, Answers second!)
house_ai.fit(X_houses, y_prices)

# 3. Predict price for 3 Bedrooms and 2 Bathrooms
new_house = house_ai.predict([[3, 2]])

print(f"🏠 Predicted price for 3 Bed, 2 Bath: ${new_house[0]:.0f},000")
# Out:
# 🏠 Predicted price for 3 Bed, 2 Bath: $560,000

# %% [markdown]
# ### Exercise 4: The Debugging Challenge
# A junior developer tried to write an AI to predict pizza delivery time based on distance (km).
#
# **However, their code has TWO bugs.** It will crash when you run it.
# 1. Read the error messages carefully.
# 2. Figure out what went wrong (Hint: look at the order of `.fit()`, and how `.predict()` is formatted).
# 3. Fix both bugs so it prints the final answer successfully!

# %%
# 👇 FIX THE TWO BUGS IN THIS CODE 👇

pizza_ai = LinearRegression()

distance_km  = np.array([[2], [4], [6], [8]])
time_minutes = np.array([15, 25, 35, 45])

# BUG 1 IS ON THIS LINE:
pizza_ai.fit(distance_km, time_minutes)

# BUG 2 IS ON THIS LINE (Predicting for a 5km trip):
pizza_pred = pizza_ai.predict([[5]])

print(f"🍕 A 5km trip will take {pizza_pred[0]:.0f} minutes.")
# Out:
# 🍕 A 5km trip will take 30 minutes.

# %% [markdown]
# ### Exercise 5: Build It From Scratch 🏆
# This is the ultimate challenge — no blanks, no hints. Write all the code yourself.
#
# **The Problem:**
# You work at a gym. You want to build an AI that predicts how many calories someone burns based on how many minutes they exercised.
#
# Here is your data:
# | Minutes Exercised | Calories Burned |
# |---|---|
# | 10 | 80 |
# | 20 | 160 |
# | 30 | 250 |
# | 45 | 370 |
# | 60 | 500 |
#
# **Your Task:**
# Write code to: **(1)** load this data, **(2)** create and train an AI, and **(3)** predict calories burned for **35 minutes** of exercise.
# Print the result in a nice sentence.

# %%
# 👇 WRITE ALL THE CODE YOURSELF IN THIS CELL 👇
# No blanks — you've got this!

# Step 1: Create the data arrays (X for minutes, y for calories)
X_minutes = ([[10], [20], [30], [45], [60]])
y_calories = ([80, 160, 250, 370, 500])

# Step 2: Create and train the AI
exercise_ai = LinearRegression()
exercise_ai.fit(X_minutes, y_calories)

# Step 3: Predict calories for 35 minutes and print the result
exercise_pred = exercise_ai.predict([[35]])

print(f"A 35 minute workout will burn {exercise_pred[0]:.0f} minutes.")
# Out:
# A 35 minute workout will burn 289 minutes.

# %% [markdown]
# ---
# ## ✅ Lesson 1 Complete!
# Amazing work! You are officially writing Artificial Intelligence code.
#
# **Next up:** Lesson 02 — We will look at the Machine Learning Pipeline. How do we collect data, clean it, and make sure our AI isn't biased?
#
# ---
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## 🔑 Answer Key
#
# ### Exercise 1
# ```python
# bug_ai = LinearRegression()
# bug_ai.fit(bug_wings, bug_species)
# result = bug_ai.predict([[890]])
# ```
#
# ### Exercise 2
# ```
# "Predicting tomorrow's temperature": "regression"
# "Grouping shoppers":                 "clustering"
# "Labelling email as Spam":           "classification"
# "Labelling X-Ray as Broken":         "classification"
# ```
#
# ### Exercise 3
# ```python
# house_ai = LinearRegression()
# house_ai.fit(X_houses, y_prices)
# new_house = house_ai.predict([[3, 2]])
# ```
#
# ### Exercise 4 — Two bugs fixed:
# ```python
# # BUG 1: .fit() needs inputs first, then answers
# pizza_ai.fit(distance_km, time_minutes)
#
# # BUG 2: .predict() needs double brackets [[value]]
# pizza_pred = pizza_ai.predict([[5]])
# ```
#
# ### Exercise 5 — Sample answer:
# ```python
# X_minutes = np.array([[10],[20],[30],[45],[60]])
# y_calories = np.array([80, 160, 250, 370, 500])
# gym_ai = LinearRegression()
# gym_ai.fit(X_minutes, y_calories)
# result = gym_ai.predict([[35]])
# print(f"🏋️ Predicted calories burned in 35 minutes: {result[0]:.0f}")
# ```
